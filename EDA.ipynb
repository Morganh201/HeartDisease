# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, classification_report, mutual_info_score
from sklearn import metrics

# %%
df = pd.read_csv("heart_train.csv")
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#       id  Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0      0   40   M           ATA        140          289          0     Normal
# 1      1   49   F           NAP        160          180          0     Normal
# 2      2   37   M           ATA        130          283          0         ST
# 3      3   48   F           ASY        138          214          0     Normal
# 4      4   39   M           NAP        120          339          0     Normal
# ..   ...  ...  ..           ...        ...          ...        ...        ...
# 638  638   45   M            TA        110          264          0     Normal
# 639  639   68   M           ASY        144          193          1     Normal
# 640  640   57   M           ASY        130          131          0     Normal
# 641  641   57   F           ATA        130          236          0        LVH
# 642  642   38   M           NAP        138          175          0     Normal
#
# ...

# %% [markdown]
# ### Univariate Analysis on Variables

# %%
plt.title("Percentage of Heart Disease")
plt.pie([len(df) - df['HeartDisease'].sum(), df['HeartDisease'].sum()], labels = [0, 1], autopct='%1.1f%%')
print("Num of Heart Disease: ", df['HeartDisease'].sum())
print("Num of No Heart Disease: ", len(df) - df['HeartDisease'].sum())
plt.show()
# Out:
# Num of Heart Disease:  359
# Num of No Heart Disease:  284

# %% [markdown]
# #### Continuous Variables

# %%
plt.figure(figsize=(12, 12))
cont_attributes = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
for i in range(len(cont_attributes)):
    plt.subplot(3, 2, i+1)
    plt.title(f"Distribution of {cont_attributes[i]}")
    plt.xlabel(cont_attributes[i])
    plt.ylabel("Num of ppl")
    plt.hist(df[cont_attributes[i]].loc[df['HeartDisease']==0], bins=40, alpha=0.5, label="No Heart Disease")
    plt.hist(df[cont_attributes[i]].loc[df['HeartDisease']==1], bins=40, alpha=0.5, label='Heart Disease')
    plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Discrete Variables

# %%
df[disc_attributes[i]].unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
plt.figure(figsize=(12, 12))
disc_attributes = ['ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope']
for i in range(len(disc_attributes)):
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 8
#       6     plt.xlabel(disc_attributes[i])
#       7     plt.ylabel("Num of ppl")
# ----> 8     plt.bar(x=df[disc_attributes[i]].unique(), height=df[disc_attributes[i]].loc[df['HeartDisease']==0])
#       9     plt.legend()
#      10 plt.show()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2439, in bar(x, height, width, bottom, align, data, **kwargs)
#    2435 @_copy_docstring_and_deprecators(Axes.bar)
#    2436 def bar(
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
