# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.neighbors import LocalOutlierFactor
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold

from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
import xgboost as xgb
from sklearn.neighbors import KNeighborsClassifier, RadiusNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import RidgeClassifier
from sklearn.svm import SVC

from sklearn.metrics import mean_absolute_error, classification_report, mutual_info_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df = pd.read_csv('heart_train.csv')
df = df.drop(['Unnamed: 0', 'id'], axis=1)
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   39   M           NAP        120          339          0     Normal    170
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
# Change Sex to 1 or 0

df['Sex'] = df['Sex'].replace({'M': 1, 'F': 0})
df['ChestPainType'] = df['ChestPainType'].replace({"TA": 1, "ATA": 2, "NAP": 3, "ASY": 4})
df['RestingECG'] = df['RestingECG'].replace({"Normal": 0, "ST": 1, "LVH": 2})
df['ExerciseAngina'] = df['ExerciseAngina'].replace({'N': 0, "Y": 1})
df['ST_Slope'] = df['ST_Slope'].replace({'Up': 1, "Flat": 2, "Down": 3})
df
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              2        140          289          0           0
# 1     49    0              3        160          180          0           0
# 2     37    1              2        130          283          0           1
# 3     48    0              4        138          214          0           0
# 4     39    1              3        120          339          0           0
# ..   ...  ...            ...        ...          ...        ...         ...
# 638   45    1              1        110          264          0           0
# 639   68    1              4        144          193          1           0
# 640   57    1              4        130          131          0           0
# 641   57    0              2        130          236          0           2
# 642   38    1              3        138          175          0           0
#
# ...

# %%
def outlier(attribute):
    # calculate IQR for column Height
    Q1 = df[attribute].quantile(0.25)
    Q3 = df[attribute].quantile(0.75)
    IQR = Q3 - Q1

    # identify outliers
    threshold = 1.5
    outliers = df[(df[attribute] < Q1 - threshold * IQR) | (df[attribute] > Q3 + threshold * IQR)]

    return outliers

# %%
#attributes = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
#for attribute in attributes:
#    outliers = outlier(attribute)
#    df = df.drop(outliers.index, errors = 'ignore')

# %%
df[df['Oldpeak'].apply(type) != int]
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              2        140          289          0           0
# 1     49    0              3        160          180          0           0
# 2     37    1              2        130          283          0           1
# 3     48    0              4        138          214          0           0
# 4     39    1              3        120          339          0           0
# ..   ...  ...            ...        ...          ...        ...         ...
# 638   45    1              1        110          264          0           0
# 639   68    1              4        144          193          1           0
# 640   57    1              4        130          131          0           0
# 641   57    0              2        130          236          0           2
# 642   38    1              3        138          175          0           0
#
# ...

# %%
X = df.drop(['HeartDisease'], axis=1)
y = df['HeartDisease']

# %%
X.duplicated().sum()
# Out:
# 0

# %%
clf = LocalOutlierFactor(n_neighbors=10)
outlier_values = clf.fit_predict(X)
outlier_values.max()
# Out:
# 1

# %%
plt.bar([0, 1], y.value_counts())
plt.show()

# %%
smote = SMOTE(random_state=0)
X_res, y_res = smote.fit_resample(X, y)

# %%
scaler = StandardScaler()
X_res = scaler.fit_transform(X_res)

# %%
X_train, val_X, y_train, val_y = train_test_split(X_res, y_res, test_size=0.3, random_state=2)

# %%
def mlmodel(model, model_name, X_train, y_train, val_X, val_y):
    model.fit(X_train, y_train)
    predictions = model.predict(val_X)

    print(model_name)
    print(classification_report(predictions, val_y))
    fpr, tpr, threshold = metrics.roc_curve(val_y, predictions)
    auc = metrics.roc_auc_score(val_y, predictions)
    plt.plot(fpr, tpr)
    plt.title("ROC curve")
    plt.ylabel("True Positive Rate")
    plt.xlabel("False Positive Rate")
    plt.show()

    confusion_matrix = metrics.confusion_matrix(val_y, predictions)
    display = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=[False, True])
    display.plot()
    plt.show()

# %%
rforest = RandomForestClassifier(random_state=2)
exforest = ExtraTreesClassifier(random_state=2)
reg = xgb.XGBClassifier(tree_method="hist", device="cuda", learning_rate=0.1, max_depth=7, subsample=0.7, random_state=42)
kneigh = KNeighborsClassifier(n_neighbors=10)
rneigh = RadiusNeighborsClassifier(radius=1)
gnb = GaussianNB()
lda = LinearDiscriminantAnalysis()
ridge = RidgeClassifier()
svm = SVC(random_state=0)

# %%
models = [rforest, exforest, reg, kneigh, gnb, lda, ridge, svm]
for model in models:
    mlmodel(model, str(model), X_train, y_train, val_X, val_y)

# %%
max_scores = []
for i in range(100):
    X_train, val_X, y_train, val_y = train_test_split(X_res, y_res, test_size=0.3, random_state=i)
    for j in range(100, 200):
        exforest = ExtraTreesClassifier(random_state=j)
        exforest.fit(X_train, y_train)
        predictions = exforest.predict(val_X)
        max_scores.append((metrics.accuracy_score(predictions, val_y), i, j))

# %%
max_scores = pd.DataFrame(max_scores, columns=['Accuracy', 'random_state_1', 'random_state_2'])
max_scores.loc[max_scores['Accuracy'] == max_scores['Accuracy'].max()]
# Out:
#     Accuracy  random_state_1  random_state_2
# 10  0.907407               0             178
# 22  0.907407               0             190

# %%
X_train, val_X, y_train, val_y = train_test_split(X_res, y_res, test_size=0.3, random_state=42)
exforest = ExtraTreesClassifier(random_state=168)
exforest.fit(X_train, y_train)
predictions = exforest.predict(val_X)
print(classification_report(predictions, val_y))

fpr, tpr, threshold = metrics.roc_curve(val_y, predictions)
auc = metrics.roc_auc_score(val_y, predictions)
plt.plot(fpr, tpr)
plt.title("ROC curve")
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.show()

confusion_matrix = metrics.confusion_matrix(val_y, predictions)
display = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=[False, True])
display.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91       101
#            1       0.92      0.91      0.92       115
#
#     accuracy                           0.91       216
#    macro avg       0.91      0.91      0.91       216
# weighted avg       0.91      0.91      0.91       216

# %%
test_X = pd.read_csv('heart_test.csv')
ids = test_X['id']
test_X = test_X.drop(['Unnamed: 0', 'id'], axis=1)

test_X['Sex'] = test_X['Sex'].replace({'M': 1, 'F': 0})
test_X['ChestPainType'] = test_X['ChestPainType'].replace({"TA": 1, "ATA": 2, "NAP": 3, "ASY": 4})
test_X['RestingECG'] = test_X['RestingECG'].replace({"Normal": 0, "ST": 1, "LVH": 2})
test_X['ExerciseAngina'] = test_X['ExerciseAngina'].replace({'N': 0, "Y": 1})
test_X['ST_Slope'] = test_X['ST_Slope'].replace({'Up': 1, "Flat": 2, "Down": 3})

test_X = scaler.fit_transform(test_X)

predictions = exforest.predict(test_X)
predictions = pd.DataFrame({'id': ids, 'output': predictions})
predictions = predictions.set_index('id')
submission = predictions.to_csv("submission1.csv")
# index=False

# %%
predictions
# Out:
#      output
# id
# 643       1
# 644       1
# 645       0
# 646       1
# 647       0
# ..      ...
# 913       1
# 914       0
# 915       1
# 916       1
# 917       1
#
# [275 rows x 1 columns]

# %%
y_train.value_counts()
# Out:
# 1    273
# 0    273
# Name: HeartDisease, dtype: int64
